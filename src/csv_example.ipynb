# %%
import csv

# %%
csvfile = open('../price/AAPL.csv', newline='')

# %%
with open('../price/AAPL.csv','r') as f:
    data= f.readlines()

# %%
data
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume\n',
#  '1982-11-30,0.128906,0.142857,0.128348,0.142299,0.110259,159196800\n',
#  '1982-12-01,0.142299,0.150670,0.142299,0.145089,0.112421,206841600\n',
#  '1982-12-02,0.145089,0.147321,0.142857,0.145089,0.112421,164729600\n',
#  '1982-12-03,0.143415,0.143415,0.140067,0.141741,0.109827,47577600\n',
#  '1982-12-06,0.141741,0.150670,0.140625,0.149554,0.115881,146585600\n',
#  '1982-12-07,0.149554,0.154576,0.146205,0.151228,0.117178,167283200\n',
#  '1982-12-08,0.151228,0.155692,0.147321,0.147879,0.114583,112313600\n',
#  '1982-12-09,0.145647,0.145647,0.138393,0.140625,0.108962,194656000\n',
#  '1982-12-10,0.138393,0.138393,0.128906,0.130580,0.101179,167484800\n',
#  '1982-12-13,0.129464,0.129464,0.127790,0.127790,0.099017,95379200\n',
#  '1982-12-14,0.127790,0.135603,0.125000,0.126674,0.098152,270054400\n',
#  '1982-12-15,0.126674,0.127232,0.123326,0.126116,0.097720,130793600\n',
# ...

# %%
import h5py

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/pq/px23cdxd711ckxwvb5g8vmlm0000gn/T/ipykernel_23329/3648170110.py in <module>
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'
